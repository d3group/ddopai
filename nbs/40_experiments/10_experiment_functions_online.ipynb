# %% [markdown]
# # Experiment functions
#
# > Functions to run experiments more efficiently. The usage of these functions is optional and they are only compatible with agents defined in this package. Using agents from other packages such as Stable Baselines or RLlib may require using their own experiment functions.

# %%
#| default_exp experiments.experiment_functions_online

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export

from abc import ABC, abstractmethod
from typing import Union, List, Tuple, Dict, Literal
import logging
from datetime import datetime  
import numpy as np
import sys
import wandb

from ddopai.envs.base import BaseEnvironment
from ddopai.agents.base import BaseAgent

import importlib

from tqdm import tqdm, trange

# Think about how to handle mushroom integration.
from mushroom_rl.core import Core

# %%
#| export

class EarlyStoppingHandler():

    '''
    Class to handle early stopping during experiments. The EarlyStoppingHandler handler calculates the average
    score over the last "patience" epochs and compares it to the average score over the previous "patience" epochs.
    Note that one epoch we define here as time in between evaluating on a validation set, for supervised learning
    typically one epoch is one pass through the training data. For reinforcement learning, in between each evaluation
    epoch there may be less than one, one, or many episodes played in the training environment.

    '''
    def __init__(
        self,
        patience: int = 50, # Number of epochs to evaluate for stopping
        warmup: int = 100, # How many initial epochs to wait before evaluating
        criteria: str = "J",  # Whether to use discounted rewards J or total rewards R as criteria
        direction: str = "max"  # Whether reward shall be maximized or minimized
    ):

        self.history = list()
        self.patience = patience
        if warmup is None or warmup < patience * 2:
            warmup = patience * 2
        self.warmup = warmup
        self.criteria = criteria
        self.direction = direction

    def add_result(self,
                    J: float, # Return (discounted rewards) of the last epoch
                    R: float, # Total rewards of the last epoch
                    ) -> bool:

        """
        Add the result of the last epoch to the history and check if the experiment should be stopped.

        """
        if self.criteria == "J":
            self.history.append(J)
        elif self.criteria == "R":
            self.history.append(R)
        else:
            raise ValueError("Criteria must be J or R")
        
        if len(self.history) >= self.warmup:
            if self.direction == "max":
                if sum(self.history[-self.patience*2:-self.patience]) >= sum(self.history[-self.patience:]):
                    return True
                else:
                    return False
            elif self.direction == "min":
                if sum(self.history[-self.patience*2:-self.patience]) <= sum(self.history[-self.patience:]):
                    return True
                else:
                    return False
            else:
                raise ValueError("Direction must be max or min")

# %%
show_doc(EarlyStoppingHandler, title_level=2)
# Out:
# ---
#
# [source](https://github.com/opimwue/ddopai/blob/main/ddopai/experiments/experiment_functions_online.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ## EarlyStoppingHandler
#
# >      EarlyStoppingHandler (patience:int=50, warmup:int=100, criteria:str='J',
# >                            direction:str='max')
#
# *Class to handle early stopping during experiments. The EarlyStoppingHandler handler calculates the average
# score over the last "patience" epochs and compares it to the average score over the previous "patience" epochs.
# Note that one epoch we define here as time in between evaluating on a validation set, for supervised learning
# typically one epoch is one pass through the training data. For reinforcement learning, in between each evaluation
# epoch there may be less than one, one, or many episodes played in the training environment.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | patience | int | 50 | Number of epochs to evaluate for stopping |
# | warmup | int | 100 | How many initial epochs to wait before evaluating |
# | criteria | str | J | Whether to use discounted rewards J or total rewards R as criteria |
# | direction | str | max | Whether reward shall be maximized or minimized |

# %% [markdown]
# ## Helper functions
#
# > Some functions that are needed to run an experiment

# %%
#| export

class DatasetCallback:
    def __init__(self):
        self.dataset = []

    def __call__(self, dataset):
        self.dataset.append(dataset)
        
def calculate_score(
                    dataset: List,
                    env: BaseEnvironment, # Any environment inheriting from BaseEnvironment
                    ) -> Tuple[float, float]:

    """

    Calculate the total rewards R and the discounted rewards J of a dataset.

    """

    R = sum([row[0][2] for row in dataset])
    gamma = env.mdp_info.gamma
    J = sum([gamma**(t) * row[0][2] for t, row in enumerate(dataset)]) # Note: t starts at 1 so the first reward is already discounted

    return R, J

def log_info(R: float,
                J: float,
                n_epochs: int,
                tracking: Literal["wandb"], # only wandb implemented so far
                mode: Literal["train", "val", "test"]
                ):
    
    '''
    Logs the same R, J information repeatedly for n_epoochs.
    E.g., to draw a straight line in wandb for algorithmes
    such as XGB, RF, etc. that can be comparared to the learning
    curves of supervised or reinforcement learning algorithms.
    '''

    if tracking == "wandb":
        for epoch in range(n_epochs):
            wandb.log({f"{mode}/R": R, f"{mode}/J": J})
    else:
        pass

def update_best(R: float, J: float, best_R: float, best_J: float): # 
    
    """

    Update the best total rewards R and the best discounted rewards J.

    """

    if R > best_R:
        best_R = R
    if J > best_J:
        best_J = J

    return best_R, best_J

def save_agent(agent: BaseAgent, # Any agent inheriting from BaseAgent
                experiment_dir: str, # Directory to save the agent, 
                save_best: bool,
                R: float,
                J: float,
                best_R: float,
                best_J: float,
                criteria: str = "J",
                force_save = False,
                ):

    """
    Save the agent if it has improved either R or J, depending on the criteria argument,
    vs. the previous epochs

    """

    if save_best:
        if criteria == "R":
            if R == best_R:
                save_dir = f"{experiment_dir}/saved_models/best"
                agent.save(save_dir)
            elif force_save:
                save_dir = f"{experiment_dir}/saved_models/best"
                agent.save(save_dir)
        elif criteria == "J":
            if J == best_J:
                save_dir = f"{experiment_dir}/saved_models/best"
                agent.save(save_dir)
            elif force_save:
                save_dir = f"{experiment_dir}/saved_models/best"
                agent.save(save_dir)

# %% [markdown]
# ## Experiment functions
#
# > Functions to run experiments

# %%
#| export

def test_agent(agent: BaseAgent,
            env: BaseEnvironment,
            return_dataset = False,
            save_features = False,
            tracking = None, # other: "wandb",
            eval_step_info = False,
):

    """
    Tests the agent on the environment for a single episode
    """
    
    # TODO make it possible to save dataset via tracking tool

    # Run the test episode
    dataset = run_test_episode(env, agent, eval_step_info, save_features = save_features)

    # Calculate the score
    R, J = calculate_score(dataset, env)

    if tracking == "wandb":
        mode = env.mode
        wandb.log({f"{mode}/R": R, f"{mode}/J": J})

    if return_dataset:
        return R, J, dataset
    else:
        return R, J

def run_test_episode(   env: BaseEnvironment, # Any environment inheriting from BaseEnvironment
                        agent: BaseAgent, # Any agent inheriting from BaseAgent
                        eval_step_info: bool = False, # Print step info during evaluation
                        save_features: bool = False, # Save features (observation) of the dataset. Can be turned off since they sometimes become very large with many lag information

                ):

    """
    Runs an episode to test the agent's performance.
    It assumes, that agent and environment are initialized, in test/val mode
    and have done reset.
    """

    # Get initial observation
    obs = env.reset()

    dataset = []
    
    finished = False
    step = 0

    horizon = env.mdp_info.horizon
    
    while not finished:
        
        # Sample action from agent
        action = agent.draw_action(obs)

        # Take a step in the environment

        next_obs, reward, terminated, truncated, info = env.step(action)
        
        logging.debug("##### STEP: %d #####", env.index)
        logging.debug("reward: %s", reward)
        logging.debug("info: %s", info)
        logging.debug("next observation: %s", obs)
        logging.debug("truncated: %s", truncated)

        if save_features:
            sample = (obs, action, reward, next_obs, terminated, truncated) # unlike mushroom do not include policy_state
        else:
            sample = (None, action, reward, None, terminated, truncated)

        obs = next_obs
        
        dataset.append((sample, info))

        finished = terminated or truncated

        if eval_step_info:
            step += 1
            sys.stdout.write(f"\rStep {step}")
            sys.stdout.flush()

    if eval_step_info:
        print()

    return dataset



def run_experiment( agent: BaseAgent,
                    env: BaseEnvironment,

                    n_epochs: int,
                    n_steps: int = None, # Number of steps to interact with the environment per epoch. Will be ignored for direct_fit and epchos_fit agents

                    early_stopping_handler: Union[EarlyStoppingHandler, None] = None,
                    save_best: bool = True,
                    performance_criterion: str = "J", # other: "R"

                    tracking: Union[str, None]  = None, # other: "wandb"

                    results_dir: str = "results",

                    run_id: Union[str, None] = None,

                    print_freq: int = 1,

                    eval_step_info = False,

                    return_score = False,
                    
                    return_dataset = False,
                ):

    """
    Run an experiment with the given agent and environment for n_epochs. It automaticall dedects if the train mode
    of the agent is direct, epochs_fit or env_interaction and runs the experiment accordingly.

    """

    if return_score:
        R_list = []
        J_list = []

    if return_dataset:
        dataset = []
    # use start_time as id if no run_id is given
    if run_id is None:
        run_id = datetime.now().strftime("%Y%m%d_%H%M%S_%f")

    experiment_dir = f"{results_dir}/{run_id}"

    print(f"Experiment directory: {experiment_dir}")

    logging.info("Starting experiment")

    env.reset()
    callback = DatasetCallback()
    core = Core(agent, env, callbacks_fit=[callback])



    for epoch in trange(n_epochs):
        
        core.learn(n_steps=n_steps, n_steps_per_fit=1, quiet=False)
        dataset = callback.dataset
        R, J = calculate_score(dataset, env)
        if return_score:
            R_list.append(R)
            J_list.append(J)

        if ((epoch + 1) % print_freq) == 0:
            logging.info(f"Epoch {epoch + 1}: R={R}, J={J}")

        if early_stopping_handler is not None:
            stop = early_stopping_handler.add_result(J, R)
        else:
            stop = False

        if stop:
            log_info(R, J, n_epochs - epoch - 1, tracking, "val")
            logging.info(f"Early stopping after {epoch + 1} epochs")
            break

        env.train()
        agent.train()

    if return_score and return_dataset:
        return R_list, J_list, dataset
    elif return_score:
        return R_list, J_list
    elif return_dataset:
        return dataset

    logging.info(f"Evaluation after training: R={R}, J={J}")

# %%
show_doc(run_experiment)
# Out:
# ---
#
# [source](https://github.com/opimwue/ddopai/blob/main/ddopai/experiments/experiment_functions_online.py#L269){target="_blank" style="float:right; font-size:smaller"}
#
# ### run_experiment
#
# >      run_experiment (agent:ddopai.agents.base.BaseAgent,
# >                      env:ddopai.envs.base.BaseEnvironment, n_epochs:int,
# >                      n_steps:int=None, early_stopping_handler:Optional[__main_
# >                      _.EarlyStoppingHandler]=None, save_best:bool=True,
# >                      performance_criterion:str='J',
# >                      tracking:Optional[str]=None, results_dir:str='results',
# >                      run_id:Optional[str]=None, print_freq:int=1,
# >                      eval_step_info=False, return_score=False,
# >                      return_dataset=False)
#
# *Run an experiment with the given agent and environment for n_epochs. It automaticall dedects if the train mode
# of the agent is direct, epochs_fit or env_interaction and runs the experiment accordingly.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | agent | BaseAgent |  |  |
# | env | BaseEnvironment |  |  |
# | n_epochs | int |  |  |
# | n_steps | int | None | Number of steps to interact with the environment per epoch. Will be ignored for direct_fit and epchos_fit agents |
# | early_stopping_handler | Optional | None |  |
# | save_best | bool | True |  |
# | performance_criterion | str | J | other: "R" |
# | tracking | Optional | None | other: "wandb" |
# | results_dir | str | results |  |
# | run_id | Optional | None |  |
# | print_freq | int | 1 |  |
# | eval_step_info | bool | False |  |
# | return_score | bool | False |  |
# | return_dataset | bool | False |  |

# %% [markdown]
# ### Important notes on running experiments
#
#
# **Training mode**:
#
# * Agents have either a training mode ```direct_fit``` or ```epochs_fit``` or ```env_interaction```. ```direct_fit``` means that agents are called with a single call to the fit method, providing the full X and Y dataset. ```epochs_fit``` means that agents are training iteratively via epochs. It is assumed that they then have access to the dataloader.
#
# **Train, val, test mode**:
#
# * The function always sets the agent and environment to the approproate dataset mode (and thereofore indirectly the dataloader via then environment).
#
# **Early stopping**:
#
# * Can be optionally applied for ```epochs_fit``` and ```env_interaction``` agents.
#
# **Save best agent**:
#
# * The ```save_agent()``` functions, given the ```save_best```param is ```True```, will save the best agent based on the validation score.
#
# * At test time at a later point, one can then load the best agent and evaluate it on the test set (not done automatically by this function).
#
# **Logging**:
#
# * By setting logging to ```"wandb"``` the function will log J and R to wandb.

# %%
show_doc(test_agent)
# Out:
# ---
#
# [source](https://github.com/opimwue/ddopai/blob/main/ddopai/experiments/experiment_functions_online.py#L179){target="_blank" style="float:right; font-size:smaller"}
#
# ### test_agent
#
# >      test_agent (agent:ddopai.agents.base.BaseAgent,
# >                  env:ddopai.envs.base.BaseEnvironment, return_dataset=False,
# >                  save_features=False, tracking=None, eval_step_info=False)
#
# *Tests the agent on the environment for a single episode*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | agent | BaseAgent |  |  |
# | env | BaseEnvironment |  |  |
# | return_dataset | bool | False |  |
# | save_features | bool | False |  |
# | tracking | NoneType | None | other: "wandb", |
# | eval_step_info | bool | False |  |

# %%
show_doc(run_test_episode)
# Out:
# ---
#
# [source](https://github.com/opimwue/ddopai/blob/main/ddopai/experiments/experiment_functions_online.py#L208){target="_blank" style="float:right; font-size:smaller"}
#
# ### run_test_episode
#
# >      run_test_episode (env:ddopai.envs.base.BaseEnvironment,
# >                        agent:ddopai.agents.base.BaseAgent,
# >                        eval_step_info:bool=False, save_features:bool=False)
#
# *Runs an episode to test the agent's performance.
# It assumes, that agent and environment are initialized, in test/val mode
# and have done reset.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | env | BaseEnvironment |  | Any environment inheriting from BaseEnvironment |
# | agent | BaseAgent |  | Any agent inheriting from BaseAgent |
# | eval_step_info | bool | False | Print step info during evaluation |
# | save_features | bool | False | Save features (observation) of the dataset. Can be turned off since they sometimes become very large with many lag information |

# %% [markdown]
# Usage example for ```test_agent()```:

# %%
from ddopai.envs.pricing.dynamic import DynamicPricingEnv
from ddopai.dataloaders.online import OnlineDataLoader
from ddopai.agents.dynamic_pricing.greedy import GreedyAgent
from ddopai.envs.actionprocessors import ClipAction

# %%
from ddopai.agents.dynamic_pricing.utils import GLMLink, get_price_function

# %%
def g(x):
    return x
def g_inv(x):
    return x
def g_prime(x):
    return 1

# %%
X = np.ones((1001, 1, 1))
#X = np.concatenate((X, np.random.normal(0, 1, (1001, 1, 1))), axis=2)
epsilon = np.random.multivariate_normal(np.zeros(1), 0.01*np.eye(1), 1001)
dataloader = OnlineDataLoader(X = X, alpha=np.array([[1.1]]), beta=np.array([[-0.5]]), epsilon = epsilon, normalize_features={'normalize': False})
clip = ClipAction(0, 10)
env = DynamicPricingEnv(alpha=np.array([[10]]), beta=np.array([[-1]]), p_bound_low=0, p_bound_high=10, dataloader=dataloader, return_truncation=False, mode="train")


link = GLMLink(g=g, g_inv=g_inv, g_prime=g_prime, link='linear')
price_function = get_price_function()

agent = GreedyAgent(env.mdp_info, ex_prices=np.array([[0.5], [1]]), g=link, price_function=price_function, actionprocessors=[clip], )

# %%
dataset = run_experiment(agent, env, 1, 100, return_dataset=True)
# Out:
# INFO:root:Starting experiment
# Experiment directory: results/20250107_102910_649667
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# INFO:root:Epoch 1: R=55.38073297131688, J=55.38073297131688
# 100%|██████████| 1/1 [00:00<00:00, 41.83it/s]

# %%
dataset
# Out:
# [[(array([[1.]]),
#    array([0.5]),
#    np.float64(0.4665617338187174),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([1.]),
#    np.float64(0.4775699433199705),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.76208224]),
#    np.float64(0.5113009575539341),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.75717049]),
#    np.float64(0.5127244003314367),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.75516598]),
#    np.float64(0.47961955075524),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.74917289]),
#    np.float64(0.5362593254189385),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.75157983]),
#    np.float64(0.5660984901385637),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.75630307]),
#    np.float64(0.5983117924120104),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.76384606]),
#    np.float64(0.5952800473137624),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77128605]),
#    np.float64(0.6167541920993368),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78193305]),
#    np.float64(0.4969175093695583),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77340721]),
#    np.float64(0.5724057727022217),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77688552]),
#    np.float64(0.6024871043054643),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78399006]),
#    np.float64(0.5916899686987227),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.79009774]),
#    np.float64(0.5470530002367517),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78909032]),
#    np.float64(0.558409488522042),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78991574]),
#    np.float64(0.6001317545605496),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.79664997]),
#    np.float64(0.4984809522479735),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78734553]),
#    np.float64(0.4421594787833592),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7751431]),
#    np.float64(0.5680299300947903),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77631284]),
#    np.float64(0.5565743440215066),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7768119]),
#    np.float64(0.5026667762970245),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7742395]),
#    np.float64(0.5354613555427999),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77377268]),
#    np.float64(0.6224291586938807),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7768348]),
#    np.float64(0.6137590483276182),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78013811]),
#    np.float64(0.5139532100879833),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7777942]),
#    np.float64(0.5208679312165384),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77632464]),
#    np.float64(0.564922784469005),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77700191]),
#    np.float64(0.5574939245720555),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77734943]),
#    np.float64(0.5611247358245132),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77784387]),
#    np.float64(0.5621229408193689),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77837309]),
#    np.float64(0.4765782296021424),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7750386]),
#    np.float64(0.6516413633154419),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77814962]),
#    np.float64(0.5940177567619662),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77994142]),
#    np.float64(0.4500644985812309),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77502302]),
#    np.float64(0.6384914999578557),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77737366]),
#    np.float64(0.5922188587832661),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77879146]),
#    np.float64(0.6476358580842728),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7826175]),
#    np.float64(0.5151475578460921),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78037076]),
#    np.float64(0.6876874296901254),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78633884]),
#    np.float64(0.5973720727026264),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.78905481]),
#    np.float64(0.4365836196356101),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77953845]),
#    np.float64(0.3706219622760639),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77287808]),
#    np.float64(0.42924750045825066),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77187157]),
#    np.float64(0.6193638940986145),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77215167]),
#    np.float64(0.5214161528481821),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7720051]),
#    np.float64(0.6375575605994267),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77238311]),
#    np.float64(0.6642452452416622),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77302648]),
#    np.float64(0.5886612767827807),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77330833]),
#    np.float64(0.5335597968672923),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77311331]),
#    np.float64(0.583700350771713),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77335242]),
#    np.float64(0.5654886878491657),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77344625]),
#    np.float64(0.628695380316067),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77412049]),
#    np.float64(0.5874307101829433),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77448136]),
#    np.float64(0.6584900301108509),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77579352]),
#    np.float64(0.6487268705335456),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77741123]),
#    np.float64(0.5443630134507179),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77701615]),
#    np.float64(0.6384054477380736),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77875567]),
#    np.float64(0.5678936411989194),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77893502]),
#    np.float64(0.5685970676518396),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77913342]),
#    np.float64(0.4492550548449788),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77581727]),
#    np.float64(0.37765871770419207),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7729923]),
#    np.float64(0.6355091155856627),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77329772]),
#    np.float64(0.4864005592354484),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77293333]),
#    np.float64(0.6327598379808876),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77319918]),
#    np.float64(0.6719959473490076),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77371278]),
#    np.float64(0.5567524684545159),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7736907]),
#    np.float64(0.486037456437491),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77322211]),
#    np.float64(0.5966149731998445),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77338603]),
#    np.float64(0.5083054555959144),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77313211]),
#    np.float64(0.5482074460499986),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77309105]),
#    np.float64(0.4954058861771307),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77285981]),
#    np.float64(0.5285080449301908),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77278132]),
#    np.float64(0.5067035000120576),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77266313]),
#    np.float64(0.5411149469736982),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77263465]),
#    np.float64(0.4360328596395975),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77243072]),
#    np.float64(0.510871774979121),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77239321]),
#    np.float64(0.39072026185158737),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77227993]),
#    np.float64(0.6171446237587871),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77229459]),
#    np.float64(0.44065939224340855),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77226281]),
#    np.float64(0.5667462757108844),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77226508]),
#    np.float64(0.5132555615902904),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77225898]),
#    np.float64(0.5837847488197179),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77226325]),
#    np.float64(0.5514422367104103),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7722632]),
#    np.float64(0.609723261827707),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77227161]),
#    np.float64(0.5259122963367224),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7722669]),
#    np.float64(0.6108927067687304),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77227608]),
#    np.float64(0.6188463444952507),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77228872]),
#    np.float64(0.6114491228398405),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7723026]),
#    np.float64(0.5729639050466634),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7723081]),
#    np.float64(0.6176145999867867),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7723278]),
#    np.float64(0.474053565260805),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77229633]),
#    np.float64(0.5103787086408038),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77228505]),
#    np.float64(0.4567866909165978),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77226476]),
#    np.float64(0.6686084582820371),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77227921]),
#    np.float64(0.6314716625568559),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77229328]),
#    np.float64(0.6553331453207346),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77231702]),
#    np.float64(0.6518871961554177),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.77234859]),
#    np.float64(0.521212805154039),
#    array([[1.]]),
#    False,
#    False)],
#  [(array([[1.]]),
#    array([0.7723325]),
#    np.float64(0.41818641940069184),
#    array([[1.]]),
#    False,
#    False)]]
